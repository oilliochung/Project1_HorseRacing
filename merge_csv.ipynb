# %%
import pandas as pd
import numpy as np
import re

# %%
df1 = pd.read_csv('data/raw/2019_09_10_performance.csv')
df2 = pd.read_csv('data/raw/2019_11_12_performance.csv')
df3 = pd.read_csv('data/raw/2020_01_02_performance.csv')
df4 = pd.read_csv('data/raw/2020_03_04_performance_b.csv')
df5 = pd.read_csv('data/raw/2020_05_06_performance.csv')
df6 = pd.read_csv('data/raw/2020_07_performance.csv')
df7 = pd.read_csv('data/raw/2020_0715_performance.csv')

# %%
df_full_season = pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# %%
df_full_season.shape
# Out:
# (11459, 19)

# %%
df1.shape,df2.shape,df3.shape,df4.shape,df5.shape,df6.shape
# Out:
# ((1714, 19), (2987, 19), (2043, 19), (2126, 19), (1953, 19), (528, 19))

# %%
df1.shape[0]+df2.shape[0]+df3.shape[0]+df4.shape[0]+df5.shape[0]+df6.shape[0]
# Out:
# 11351

# %%
df_full_season=df_full_season.reset_index(drop=True)

# %%
df_full_season.to_csv('full_season_performance.csv',index=False)

# %%
df_csv= pd.read_csv('full_season_performance.csv')

# %%
df_csv
# Out:
#       place  horse_no                   horse      jockey      trainer  \
# 0         1       3.0  GOOD RUNNERS WAY(C127)    Z Purton     C S Shum
# 1         2       4.0       REGENCY GEM(C035)   J Moreira       W Y So
# 2         3       7.0         PROUD SKY(V406)    K Teetan         L Ho
# 3         4       2.0        LE PANACHE(V369)     A Sanna    D J Whyte
# 4         5       1.0       GOLD VELVET(V400)  L Hewitson  A T Millard
# ...     ...       ...                     ...         ...          ...
# 11454     8       6.0        ENCORE BOY(A177)      T H So      P F Yiu
# 11455     9      12.0    RACING FIGHTER(B285)    M F Poon      C H Yip
# 11456    10       9.0         SUNNY BOY(A379)    V Borges      J Moore
# 11457    11       8.0    SAUL'S SPECIAL(A293)    K H Chan    C W Chang
# 11458    12       2.0   YEE CHEONG BABY(C273)    C L Chau     K H Ting
#
#        actual_weight declared_horse_weight draw    lbw  \
# 0                131                  1072    6      -
# ...
